# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
from scipy.stats import kstest
from scipy.stats import spearmanr

# %%
eth_4h = pd.read_csv("ETHUSDT-4h-2020-2024.csv",delimiter=';')

# %%
#change timestamp into datetime
def timestamp_to_datetime(timestamp:list)->list:
    datetime = []
    for i in timestamp:
        datetime.append(dt.fromtimestamp(int(i)/1000))
    return datetime

eth_4h['open_time'] = timestamp_to_datetime(eth_4h['open_time'])
eth_4h['close_time'] = timestamp_to_datetime(eth_4h['close_time'])

# %%
eth_4h.tail()
# Out:
#                 open_time     open     high      low    close      volume  \
# 10382 2024-09-30 11:00:00  2628.64  2642.99  2621.81  2636.70  258982.869
# 10383 2024-09-30 15:00:00  2636.70  2642.48  2590.72  2627.97  683349.428
# 10384 2024-09-30 19:00:00  2627.97  2638.15  2592.05  2595.05  429091.015
# 10385 2024-09-30 23:00:00  2595.05  2609.44  2572.82  2594.49  488562.373
# 10386 2024-10-01 03:00:00  2594.50  2616.86  2575.54  2601.49  343586.791
#
#                    close_time  quote_volume   count  taker_buy_volume  \
# 10382 2024-09-30 14:59:59.999  6.821363e+08  360528        137356.722
# 10383 2024-09-30 18:59:59.999  1.788853e+09  782211        334382.805
# 10384 2024-09-30 22:59:59.999  1.123442e+09  613753        199132.875
# 10385 2024-10-01 02:59:59.999  1.267736e+09  644795        241391.344
# 10386 2024-10-01 06:59:59.999  8.936541e+08  498133        172148.092
#
#        taker_buy_quote_volume  ignore
# 10382            3.618291e+08       0
# 10383            8.755135e+08       0
# 10384            5.215090e+08       0
# 10385            6.265518e+08       0
# 10386            4.477334e+08       0

# %%
log_ret = (np.log(eth_4h.close) - np.log(eth_4h.close.shift(1)))[1:]

# %%
#kolmogorov-smirnov test
kstest(log_ret,"norm")
# Out:
# KstestResult(statistic=0.47118659742005786, pvalue=0.0, statistic_location=0.05584191309408748, statistic_sign=1)

# %%
# tidak normal

# %%
def lag_logret(close:list[float],lag_n:int)->pd.DataFrame:
    log_ret = (np.log(close) - np.log(close.shift(1)))[1:]

    df = pd.DataFrame()
    for i in range(1,lag_n+1):
        df[f'D{i}'] = list(log_ret[i-1:].values)+[np.nan]*(i-1)
    return df

# %%
lag_logret(eth_4h.close,42).iloc[:42,:42].corr(method='spearman')
# Out:
#            D1        D2        D3        D4        D5        D6        D7  \
# D1   1.000000 -0.203954  0.038976 -0.174945 -0.117413  0.082246 -0.042379
# D2  -0.203954  1.000000 -0.210113  0.073657 -0.120493 -0.152095  0.106393
# D3   0.038976 -0.210113  1.000000 -0.210437  0.075115 -0.117576 -0.137833
# D4  -0.174945  0.073657 -0.210437  1.000000 -0.139292  0.047727 -0.071712
# D5  -0.117413 -0.120493  0.075115 -0.139292  1.000000 -0.201523  0.074953
# D6   0.082246 -0.152095 -0.117576  0.047727 -0.201523  1.000000 -0.271372
# D7  -0.042379  0.106393 -0.137833 -0.071712  0.074953 -0.271372  1.000000
# D8   0.045296 -0.047241  0.107204 -0.138806 -0.071550  0.091970 -0.267158
# D9   0.093266  0.074143 -0.036221  0.128434 -0.078357 -0.106069  0.127947
# D10 -0.241553  0.079005  0.075440 -0.040921  0.116279 -0.078843 -0.096183
# D11  0.074467 -0.223888  0.102180  0.139454 -0.015477  0.049834 -0.105583
# D12 -0.019366  0.080788 -0.225833  0.106231  0.115307 -0.029090  0.045458
# D13  0.005267 -0.003322  0.087756 -0.175918  0.135564  0.076898 -0.026659
# D14  0.083867  0.006401 -0.015801  0.070092 -0.149664  0.160684  0.120655
# D15 -0.079329  0.063771 -0.001053 -0.091322  0.038814 -0.073171  0.191800
# D16  0.055344 -0.125517  0.063609 -0.062799 -0.144478  0.100073 -0.105907
# D17 -0.023580  0.044648 -0.136537  0.020987 -0.089539 -0.089701  0.107528
# D18  0.156308 -0.043027  0.044162 -0.184183 -0.009319 -0.039138 -0.085649
# D19 -0.239446  0.182400 -0.030062  0.119358 -0.135078 -0.081274 -0.048051
# D20  0.059396 -0.237663  0.180617 -0.026497  0.124706 -0.133133 -0.046431
# D21 -0.262296  0.069281 -0.236853  0.174783 -0.014018  0.106717 -0.141237
# D22  0.163925 -0.264889  0.070092 -0.242201  0.143181  0.002674  0.083219
# D23 -0.120979  0.129730 -0.262458  0.021635 -0.288388  0.217405 -0.025038
# D24  0.017908 -0.072847  0.126327 -0.205413  0.092618 -0.316425  0.270886
# D25  0.048051 -0.001215 -0.083219  0.076250 -0.229722  0.145774 -0.302164
# D26 -0.106069  0.028766 -0.001053 -0.099425  0.055020 -0.211733  0.136537
# D27 -0.080139 -0.085001  0.031683  0.066040 -0.060368 -0.011101 -0.218216
# D28  0.131999 -0.083867 -0.089539 -0.029090  0.036383  0.001215  0.000891
# D29 -0.036707  0.146098 -0.094239 -0.077871 -0.013370  0.033790  0.022770
# D30  0.167166 -0.071226  0.166194 -0.100235 -0.133944 -0.001053 -0.033142
# D31 -0.324528  0.198282 -0.084029  0.167653 -0.019853 -0.145450  0.081598
# D32  0.010615 -0.313832  0.198606 -0.058585  0.170246 -0.041245 -0.153229
# D33  0.016449  0.016125 -0.347865  0.158577 -0.052913  0.214164 -0.004619
# D34  0.008994  0.014667  0.037193 -0.338951  0.134268 -0.072360  0.168463
# D35  0.212219 -0.000081  0.004133  0.003160 -0.343489  0.177700 -0.053075
# D36 -0.038976  0.192124 -0.013694 -0.051292 -0.001378 -0.299246  0.223402
# D37  0.083705 -0.087432  0.196662 -0.049834 -0.125517  0.045296 -0.346730
# D38 -0.067823  0.083543 -0.086460  0.199417 -0.068309 -0.138968  0.012236
# D39 -0.242039 -0.105259  0.077546 -0.132323  0.134430 -0.022932 -0.167490
# D40  0.273155 -0.265862 -0.098938  0.056154 -0.201037  0.153877 -0.109310
# D41  0.114983  0.228426 -0.287578 -0.194555 -0.003160 -0.099263  0.159063
# D42 -0.027307  0.110283  0.230208 -0.268617 -0.191151 -0.012236 -0.122762
#
#            D8        D9       D10  ...       D33       D34       D35  \
# D1   0.045296  0.093266 -0.241553  ...  0.016449  0.008994  0.212219
# D2  -0.047241  0.074143  0.079005  ...  0.016125  0.014667 -0.000081
# D3   0.107204 -0.036221  0.075440  ... -0.347865  0.037193  0.004133
# D4  -0.138806  0.128434 -0.040921  ...  0.158577 -0.338951  0.003160
# D5  -0.071550 -0.078357  0.116279  ... -0.052913  0.134268 -0.343489
# D6   0.091970 -0.106069 -0.078843  ...  0.214164 -0.072360  0.177700
# D7  -0.267158  0.127947 -0.096183  ... -0.004619  0.168463 -0.053075
# D8   1.000000 -0.258245  0.132161  ... -0.157281  0.006239  0.163439
# D9  -0.258245  1.000000 -0.266996  ...  0.045134 -0.160846 -0.005429
# D10  0.132161 -0.266996  1.000000  ... -0.033790  0.042703 -0.164735
# D11 -0.105259  0.169273 -0.277206  ...  0.116441 -0.073495  0.056154
# D12 -0.102666 -0.110283  0.169597  ... -0.025038  0.098938 -0.054047
# D13  0.052913 -0.060530 -0.108662  ... -0.135240 -0.051292  0.095049
# D14 -0.030224  0.036869 -0.056478  ...  0.021635 -0.103476 -0.090349
# D15  0.118872 -0.085974  0.040434  ... -0.247063  0.071388 -0.119196
# D16  0.190341  0.066364 -0.084515  ...  0.209140 -0.215785  0.086136
# D17 -0.109148  0.154039  0.065392  ... -0.175918  0.231343 -0.218702
# D18  0.105745 -0.131999  0.157929  ...  0.120979 -0.143019  0.226157
# D19 -0.083381  0.152743 -0.125355  ... -0.188558  0.083543 -0.133620
# D20 -0.058585 -0.069767  0.139292  ... -0.028928 -0.189693  0.071874
# D21 -0.044486 -0.059882 -0.070254  ...  0.088567 -0.038003 -0.191151
# D22 -0.146260 -0.065230 -0.044648  ... -0.171704  0.085163 -0.033304
# D23  0.086460 -0.187424 -0.050320  ...  0.129406 -0.151446  0.094401
# D24 -0.033466  0.139454 -0.181752  ... -0.179159  0.127623 -0.177538
# D25  0.263755 -0.060206  0.141074  ... -0.008022 -0.145774  0.120817
# D26 -0.298436  0.237339 -0.065392  ...  0.223888 -0.001378 -0.141885
# D27  0.142857 -0.261648  0.242201  ... -0.125841  0.185641 -0.000243
# D28 -0.227291  0.110121 -0.265862  ...  0.103638 -0.090997  0.180780
# D29  0.007698 -0.215299  0.111255  ... -0.046917  0.113848 -0.100397
# D30  0.031683 -0.017584 -0.208654  ... -0.195203 -0.094563  0.161980
# D31 -0.044810  0.065554 -0.029414  ...  0.137995 -0.160360 -0.146260
# D32  0.080301 -0.020339  0.069119  ... -0.299084  0.118386 -0.156146
# D33 -0.157281  0.045134 -0.033790  ...  1.000000 -0.264079  0.087432
# D34  0.006239 -0.160846  0.042703  ... -0.264079  1.000000 -0.233125
# D35  0.163439 -0.005429 -0.164735  ...  0.087432 -0.233125  1.000000
# D36 -0.062799  0.135564 -0.010453  ... -0.198930  0.141885 -0.248521
# D37  0.226967 -0.113524  0.138481  ... -0.115469 -0.197310  0.168301
# D38 -0.350620  0.227129 -0.114658  ...  0.110121 -0.157281 -0.177052
# D39  0.015639 -0.377360  0.226319  ... -0.097966  0.118224 -0.133944
# D40 -0.159063 -0.014342 -0.365692  ...  0.267806 -0.127461  0.166842
# D41 -0.112390 -0.216919 -0.015639  ... -0.162305  0.326797 -0.123410
# D42  0.158253 -0.096021 -0.216271  ... -0.003646 -0.181752  0.335224
#
#           D36       D37       D38       D39       D40       D41       D42
# D1  -0.038976  0.083705 -0.067823 -0.242039  0.273155  0.114983 -0.027307
# D2   0.192124 -0.087432  0.083543 -0.105259 -0.265862  0.228426  0.110283
# D3  -0.013694  0.196662 -0.086460  0.077546 -0.098938 -0.287578  0.230208
# D4  -0.051292 -0.049834  0.199417 -0.132323  0.056154 -0.194555 -0.268617
# D5  -0.001378 -0.125517 -0.068309  0.134430 -0.201037 -0.003160 -0.191151
# D6  -0.299246  0.045296 -0.138968 -0.022932  0.153877 -0.099263 -0.012236
# D7   0.223402 -0.346730  0.012236 -0.167490 -0.109310  0.159063 -0.122762
# D8  -0.062799  0.226967 -0.350620  0.015639 -0.159063 -0.112390  0.158253
# D9   0.135564 -0.113524  0.227129 -0.377360 -0.014342 -0.216919 -0.096021
# D10 -0.010453  0.138481 -0.114658  0.226319 -0.365692 -0.015639 -0.216271
# D11 -0.126003 -0.065554  0.101694 -0.143019  0.147233 -0.349323 -0.039138
# D12  0.079815 -0.120006 -0.067174  0.108014 -0.156146  0.173811 -0.355806
# D13 -0.050158  0.035086 -0.136699 -0.083219  0.060854 -0.167490  0.173487
# D14  0.048862 -0.052913  0.051617 -0.124220 -0.070092  0.002998 -0.165546
# D15 -0.141723  0.115631 -0.005429  0.102990 -0.024714 -0.079491  0.013208
# D16 -0.108986 -0.067985  0.131027  0.048537  0.165546  0.022121 -0.056640
# D17  0.070578 -0.059558 -0.055182  0.161008  0.110769  0.171218  0.032331
# D18 -0.227615  0.108338 -0.038652 -0.025849  0.218864  0.113038  0.178835
# D19  0.242039 -0.284985  0.073981 -0.074953 -0.114172  0.205575  0.100073
# D20 -0.165546  0.214974 -0.272182  0.048699 -0.073333 -0.162305  0.213678
# D21  0.069281 -0.167815  0.197472 -0.278827  0.046106 -0.074467 -0.167166
# D22 -0.171866  0.078843 -0.167328  0.220485 -0.272182  0.081760 -0.081274
# D23 -0.039300 -0.103152  0.092618 -0.117413  0.281258 -0.218216  0.080950
# D24  0.066364 -0.102018 -0.113686  0.047565 -0.161980  0.184993 -0.205251
# D25 -0.204278  0.115793 -0.072036 -0.080139  0.122762 -0.160198  0.191314
# D26  0.127623 -0.190989  0.126489 -0.062313 -0.058585  0.128434 -0.153229
# D27 -0.119844  0.072685 -0.225671  0.085487 -0.148043 -0.066202  0.111255
# D28 -0.031359 -0.072360  0.107204 -0.190989  0.164087 -0.145450 -0.046917
# D29  0.166680 -0.033628 -0.061502  0.088242 -0.182886  0.132647 -0.135726
# D30 -0.048537  0.188721 -0.060368 -0.039786  0.080301 -0.089215  0.127785
# D31  0.092780 -0.091160  0.220160 -0.094725 -0.028118 -0.044162 -0.074467
# D32 -0.137509  0.071874 -0.113524  0.206871 -0.128596 -0.013370 -0.044324
# D33 -0.198930 -0.115469  0.110121 -0.097966  0.267806 -0.162305 -0.003646
# D34  0.141885 -0.197310 -0.157281  0.118224 -0.127461  0.326797 -0.181752
# D35 -0.248521  0.168301 -0.177052 -0.133944  0.166842 -0.123410  0.335224
# D36  1.000000 -0.203792  0.198930 -0.151284 -0.062799  0.145612 -0.104935
# D37 -0.203792  1.000000 -0.186938  0.228426 -0.100397  0.019853  0.140102
# D38  0.198930 -0.186938  1.000000 -0.176242  0.211733 -0.064419  0.002350
# D39 -0.151284  0.228426 -0.176242  1.000000 -0.128758  0.272020 -0.064906
# D40 -0.062799 -0.100397  0.211733 -0.128758  1.000000 -0.008832  0.255976
# D41  0.145612  0.019853 -0.064419  0.272020 -0.008832  1.000000  0.018556
# D42 -0.104935  0.140102  0.002350 -0.064906  0.255976  0.018556  1.000000
#
# [42 rows x 42 columns]

# %%
lag_logret(eth_4h.close,42).corr(method='spearman')
# Out:
#            D1        D2        D3        D4        D5        D6        D7  \
# D1   1.000000 -0.060067 -0.001014  0.004374  0.006517 -0.006185 -0.069698
# D2  -0.060067  1.000000 -0.060068 -0.001019  0.004376  0.006521 -0.006180
# D3  -0.001014 -0.060068  1.000000 -0.060125 -0.001005  0.004425  0.006576
# D4   0.004374 -0.001019 -0.060125  1.000000 -0.060098 -0.000900  0.004548
# D5   0.006517  0.004376 -0.001005 -0.060098  1.000000 -0.060133 -0.000932
# D6  -0.006185  0.006521  0.004425 -0.000900 -0.060133  1.000000 -0.060265
# D7  -0.069698 -0.006180  0.006576  0.004548 -0.000932 -0.060265  1.000000
# D8   0.010199 -0.069701 -0.006190  0.006556  0.004554 -0.000909 -0.060241
# D9   0.005769  0.010198 -0.069712 -0.006213  0.006561  0.004577 -0.000883
# D10  0.024932  0.005769  0.010201 -0.069711 -0.006213  0.006561  0.004573
# D11  0.009698  0.024941  0.005831  0.010338 -0.069755 -0.006348  0.006409
# D12  0.013272  0.009702  0.024968  0.005887  0.010324 -0.069814 -0.006412
# D13 -0.011347  0.013275  0.009726  0.025018  0.005876  0.010278 -0.069875
# D14 -0.010584 -0.011356  0.013213  0.009590  0.025057  0.006014  0.010435
# D15 -0.006130 -0.010593 -0.011433  0.013054  0.009635  0.025221  0.006198
# D16  0.010992 -0.006130 -0.010594 -0.011431  0.013054  0.009633  0.025223
# D17  0.010952  0.010988 -0.006172 -0.010683 -0.011408  0.013144  0.009734
# D18  0.023890  0.010949  0.010950 -0.006257 -0.010663 -0.011327  0.013238
# D19 -0.003634  0.023896  0.010997  0.011050 -0.006281 -0.010763 -0.011442
# D20 -0.024445 -0.003638  0.023868  0.010936  0.011065 -0.006221 -0.010695
# D21  0.019013 -0.024444 -0.003631  0.023890  0.010931  0.011046 -0.006246
# D22 -0.008648  0.019018 -0.024415 -0.003568  0.023874  0.010870  0.010977
# D23 -0.000439 -0.008651  0.018998 -0.024463 -0.003556  0.023921  0.010924
# D24  0.021632 -0.000441 -0.008675  0.018946 -0.024450 -0.003505  0.023982
# D25 -0.023310  0.021628 -0.000501 -0.008807  0.018984 -0.024323 -0.003355
# D26  0.013589 -0.023309  0.021637 -0.000481 -0.008812  0.018964 -0.024345
# D27 -0.012345  0.013595 -0.023268  0.021732 -0.000506 -0.008906  0.018858
# D28 -0.005744 -0.012353  0.013534 -0.023404  0.021768 -0.000372 -0.008756
# D29 -0.000464 -0.005750 -0.012388  0.013462 -0.023388  0.021841 -0.000292
# D30  0.012582 -0.000459 -0.005683 -0.012246  0.013427 -0.023535  0.021680
# D31  0.004842  0.012576 -0.000535 -0.005849 -0.012205  0.013592 -0.023354
# D32 -0.025148  0.004846  0.012610 -0.000465 -0.005869 -0.012275  0.013514
# D33 -0.009079 -0.025157  0.004779  0.012467 -0.000427 -0.005722 -0.012113
# D34  0.001246 -0.009074 -0.025108  0.004894  0.012437 -0.000537 -0.005848
# D35  0.021967  0.001241 -0.009119 -0.025208  0.004916  0.012532 -0.000428
# D36  0.016462  0.021964  0.001173 -0.009266 -0.025173  0.005063  0.012697
# D37  0.023490  0.016467  0.021995  0.001238 -0.009282 -0.025237  0.004993
# D38 -0.011958  0.023493  0.016505  0.022072  0.001222 -0.009355 -0.025323
# D39  0.009940 -0.011955  0.023506  0.016528  0.022067  0.001197 -0.009383
# D40  0.009349  0.009949 -0.011888  0.023665  0.016493  0.021918  0.001023
# D41 -0.007095  0.009342  0.009875 -0.012052  0.023707  0.016653  0.022102
# D42  0.006755 -0.007092  0.009364  0.009921 -0.012061  0.023667  0.016605
#
#            D8        D9       D10  ...       D33       D34       D35  \
# D1   0.010199  0.005769  0.024932  ... -0.009079  0.001246  0.021967
# D2  -0.069701  0.010198  0.005769  ... -0.025157 -0.009074  0.001241
# D3  -0.006190 -0.069712  0.010201  ...  0.004779 -0.025108 -0.009119
# D4   0.006556 -0.006213 -0.069711  ...  0.012467  0.004894 -0.025208
# D5   0.004554  0.006561 -0.006213  ... -0.000427  0.012437  0.004916
# D6  -0.000909  0.004577  0.006561  ... -0.005722 -0.000537  0.012532
# D7  -0.060241 -0.000883  0.004573  ... -0.012113 -0.005848 -0.000428
# D8   1.000000 -0.060242 -0.000880  ...  0.013490 -0.012095 -0.005866
# D9  -0.060242  1.000000 -0.060236  ... -0.023374  0.013513 -0.012116
# D10 -0.000880 -0.060236  1.000000  ...  0.021680 -0.023381  0.013515
# D11  0.004596 -0.000858 -0.060254  ... -0.000120  0.021543 -0.023264
# D12  0.006417  0.004607 -0.000858  ... -0.008751 -0.000178  0.021596
# D13 -0.006402  0.006423  0.004606  ...  0.019062 -0.008802 -0.000134
# D14 -0.069905 -0.006429  0.006430  ... -0.024684  0.019202 -0.008922
# D15  0.010409 -0.069944 -0.006423  ... -0.003364 -0.024523  0.019065
# D16  0.006197  0.010409 -0.069945  ...  0.024020 -0.003367 -0.024524
# D17  0.025209  0.006179  0.010412  ...  0.010716  0.024113 -0.003445
# D18  0.009720  0.025194  0.006183  ...  0.011034  0.010800  0.024042
# D19  0.013256  0.009740  0.025192  ... -0.006348  0.010930  0.010890
# D20 -0.011454  0.013246  0.009743  ... -0.010798 -0.006284  0.010877
# D21 -0.010692 -0.011451  0.013243  ... -0.010885 -0.010820 -0.006266
# D22 -0.006233 -0.010682 -0.011455  ...  0.012777 -0.010952 -0.010765
# D23  0.010968 -0.006242 -0.010680  ...  0.009510  0.012826 -0.010994
# D24  0.010917  0.010957 -0.006239  ...  0.025323  0.009566  0.012781
# D25  0.023961  0.010896  0.010961  ...  0.005571  0.025461  0.009453
# D26 -0.003353  0.023963  0.010895  ...  0.010681  0.005553  0.025480
# D27 -0.024331 -0.003336  0.023960  ... -0.069907  0.010585  0.005637
# D28  0.018837 -0.024361 -0.003328  ... -0.006516 -0.069779  0.010466
# D29 -0.008768  0.018825 -0.024360  ...  0.006824 -0.006444 -0.069846
# D30 -0.000267 -0.008743  0.018821  ...  0.004423  0.006675 -0.006317
# D31  0.021656 -0.000297 -0.008738  ... -0.000901  0.004592  0.006534
# D32 -0.023344  0.021671 -0.000300  ... -0.060039 -0.000975  0.004655
# D33  0.013490 -0.023374  0.021680  ...  1.000000 -0.059902 -0.001106
# D34 -0.012095  0.013513 -0.023381  ... -0.059902  1.000000 -0.059808
# D35 -0.005866 -0.012116  0.013515  ... -0.001106 -0.059808  1.000000
# D36 -0.000454 -0.005894 -0.012112  ...  0.004461 -0.000956 -0.059948
# D37  0.012708 -0.000443 -0.005898  ...  0.006716  0.004397 -0.000900
# D38  0.005005  0.012721 -0.000447  ... -0.006482  0.006640  0.004463
# D39 -0.025316  0.005009  0.012721  ... -0.069598 -0.006505  0.006660
# D40 -0.009358 -0.025291  0.005003  ...  0.010595 -0.069771 -0.006374
# D41  0.000995 -0.009388 -0.025285  ...  0.005127  0.010764 -0.069921
# D42  0.022110  0.001003 -0.009390  ...  0.026117  0.005082  0.010802
#
#           D36       D37       D38       D39       D40       D41       D42
# D1   0.016462  0.023490 -0.011958  0.009940  0.009349 -0.007095  0.006755
# D2   0.021964  0.016467  0.023493 -0.011955  0.009949  0.009342 -0.007092
# D3   0.001173  0.021995  0.016505  0.023506 -0.011888  0.009875  0.009364
# D4  -0.009266  0.001238  0.022072  0.016528  0.023665 -0.012052  0.009921
# D5  -0.025173 -0.009282  0.001222  0.022067  0.016493  0.023707 -0.012061
# D6   0.005063 -0.025237 -0.009355  0.001197  0.021918  0.016653  0.023667
# D7   0.012697  0.004993 -0.025323 -0.009383  0.001023  0.022102  0.016605
# D8  -0.000454  0.012708  0.005005 -0.025316 -0.009358  0.000995  0.022110
# D9  -0.005894 -0.000443  0.012721  0.005009 -0.025291 -0.009388  0.001003
# D10 -0.012112 -0.005898 -0.000447  0.012721  0.005003 -0.025285 -0.009390
# D11  0.013698 -0.012193 -0.005989 -0.000477  0.012530  0.005205 -0.025340
# D12 -0.023190  0.013666 -0.012229 -0.006001 -0.000558  0.012615  0.005183
# D13  0.021665 -0.023220  0.013634 -0.012238 -0.006072 -0.000485  0.012597
# D14 -0.000318  0.021748 -0.023129  0.013668 -0.012049 -0.006273 -0.000431
# D15 -0.009138 -0.000222  0.021862 -0.023094  0.013900 -0.012288 -0.006210
# D16  0.019071 -0.009139 -0.000222  0.021862 -0.023098  0.013901 -0.012286
# D17 -0.024646  0.019124 -0.009079 -0.000202  0.021986 -0.023231  0.013937
# D18 -0.003555 -0.024598  0.019181 -0.009061 -0.000085  0.021868 -0.023198
# D19  0.024179 -0.003614 -0.024668  0.019159 -0.009206  0.000062  0.021830
# D20  0.010811  0.024216 -0.003573 -0.024654  0.019246 -0.009298  0.000088
# D21  0.010906  0.010799  0.024203 -0.003578 -0.024688  0.019281 -0.009306
# D22 -0.006180  0.010872  0.010758  0.024189 -0.003668 -0.024602  0.019257
# D23 -0.010830 -0.006151  0.010903  0.010770  0.024258 -0.003735 -0.024584
# D24 -0.011065 -0.010801 -0.006115  0.010915  0.010843  0.024185 -0.003715
# D25  0.012610 -0.010988 -0.010711 -0.006086  0.011101  0.010654  0.024241
# D26  0.009483  0.012600 -0.011003 -0.010716 -0.006113  0.011130  0.010646
# D27  0.025611  0.009428  0.012539 -0.011025 -0.010850 -0.005974  0.011095
# D28  0.005459  0.025693  0.009521  0.012570 -0.010838 -0.011046 -0.005920
# D29  0.010374  0.005500  0.025741  0.009536  0.012669 -0.010943 -0.011019
# D30 -0.069664  0.010291  0.005402  0.025711  0.009333  0.012884 -0.011002
# D31 -0.006536 -0.069576  0.010405  0.005439  0.025947  0.009097  0.012951
# D32  0.006631 -0.006579 -0.069628  0.010389  0.005339  0.026055  0.009070
# D33  0.004461  0.006716 -0.006482 -0.069598  0.010595  0.005127  0.026117
# D34 -0.000956  0.004397  0.006640 -0.006505 -0.069771  0.010764  0.005082
# D35 -0.059948 -0.000900  0.004463  0.006660 -0.006374 -0.069921  0.010802
# D36  1.000000 -0.059869 -0.000803  0.004497  0.006866 -0.006591 -0.069867
# D37 -0.059869  1.000000 -0.059915 -0.000814  0.004404  0.006962 -0.006615
# D38 -0.000803 -0.059915  1.000000 -0.059928 -0.000920  0.004513  0.006932
# D39  0.004497 -0.000814 -0.059928  1.000000 -0.059975 -0.000883  0.004504
# D40  0.006866  0.004404 -0.000920 -0.059975  1.000000 -0.059764 -0.000942
# D41 -0.006591  0.006962  0.004513 -0.000883 -0.059764  1.000000 -0.059707
# D42 -0.069867 -0.006615  0.006932  0.004504 -0.000942 -0.059707  1.000000
#
# [42 rows x 42 columns]

# %%
for i in range(1,42):
    result = spearmanr(lag_logret(eth_4h.close,42).values[0],lag_logret(eth_4h.close,42).values[i])
    if result[1] < 0.05:
        print(f'p-val of spearman correlation between D1 and D{i+1}', result[1])
        print('')
# Out:
# p-val of spearman correlation between D1 and D31 0.036008118260386614

# %% [markdown]
# # Finding Outliers Date

# %%
log_ret_df = pd.DataFrame({'log_ret':log_ret.values},index=eth_4h.open_time[1:])
log_ret_df
# Out:
#                       log_ret
# open_time
# 2020-01-01 11:00:00  0.000615
# 2020-01-01 15:00:00  0.003604
# 2020-01-01 19:00:00  0.010129
# 2020-01-01 23:00:00 -0.001365
# 2020-01-02 03:00:00 -0.008917
# ...                       ...
# 2024-09-30 11:00:00  0.003062
# 2024-09-30 15:00:00 -0.003316
# 2024-09-30 19:00:00 -0.012606
# 2024-09-30 23:00:00 -0.000216
# 2024-10-01 03:00:00  0.002694
#
# [10386 rows x 1 columns]

# %%
log_ret_df = pd.DataFrame({'log_ret':log_ret.values},index=eth_4h.open_time[1:])
def find_outliers(df:pd.DataFrame,k=1.5)->pd.DataFrame:
    Q1 = np.quantile(log_ret_df.log_ret,0.25)
    Q3 = np.quantile(log_ret_df.log_ret,0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - k*IQR
    upper_bound = Q3 + k*IQR

    print("normal range is between",lower_bound,"and",upper_bound)
    return df.loc[(df.log_ret < lower_bound) | (df.log_ret > upper_bound)]

find_outliers(log_ret_df,k=1.5)
# Out:
# normal range is between -0.02662828141598883 and 0.027709176126614388
#                       log_ret
# open_time
# 2020-01-06 07:00:00  0.029703
# 2020-01-10 19:00:00  0.029136
# 2020-01-12 03:00:00 -0.026951
# 2020-01-14 07:00:00  0.036718
# 2020-01-14 19:00:00  0.029255
# ...                       ...
# 2024-09-02 15:00:00  0.030200
# 2024-09-06 19:00:00 -0.035677
# 2024-09-06 23:00:00 -0.029937
# 2024-09-17 19:00:00  0.032152
# 2024-09-23 07:00:00  0.036322
#
# [1005 rows x 1 columns]

# %%
log_ret_df.shape
# Out:
# (10386, 1)

# %%
1005/10386
# Out:
# 0.09676487579433853

# %%
winsorizing

log_ret :
kurtosis
skewness

cek apakah tanggal outliers dekat2 atau nggak

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(log_ret_df,bins=100)
plt.show()

# %%
import yfinance as yf

# %%
close_daily = yf.download(['ETH-USD']).loc['2020-1-1':'2024-10-1'].Close
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
log_ret_daily = np.log(close_daily) - np.log(close_daily.shift(1))
log_ret_daily = log_ret_daily[1:]

# %%
log_ret_2day = []

for i in range(0,log_ret_daily.shape[0],2):
    log_ret_2day.append(log_ret_daily[i])
# Out:
# /var/folders/_8/r2326rms4l37yskjs2yv3mv80000gn/T/ipykernel_6563/2868508894.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   log_ret_2day.append(log_ret_daily[i])

# %%
plt.hist(log_ret_daily,bins=100)

plt.show()

# %%
plt.hist(log_ret_2day,bins=100)

plt.show()
